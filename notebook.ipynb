# %%
import pandas as pd
import os
from datetime import datetime

# %%
# Load the Excel file
df = pd.read_excel('Superstore Dataset.xlsx')

# Display the first 5 rows of the dataframe
df.head()
# Out:
#    Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0       1  US-2019-103800 2019-01-03 2019-01-07  Standard Class    DP-13000
# 1       2  US-2019-112326 2019-01-04 2019-01-08  Standard Class    PO-19195
# 2       3  US-2019-112326 2019-01-04 2019-01-08  Standard Class    PO-19195
# 3       4  US-2019-112326 2019-01-04 2019-01-08  Standard Class    PO-19195
# 4       5  US-2019-141817 2019-01-05 2019-01-12  Standard Class    MB-18085
#
#    Customer Name      Segment        Country          City  ... Postal Code  \
# 0  Darren Powers     Consumer  United States       Houston  ...       77095
# 1  Phillina Ober  Home Office  United States    Naperville  ...       60540
# 2  Phillina Ober  Home Office  United States    Naperville  ...       60540
# 3  Phillina Ober  Home Office  United States    Naperville  ...       60540
# 4     Mick Brown     Consumer  United States  Philadelphia  ...       19143
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32484 entries, 0 to 32483
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         32484 non-null  int64
#  1   Order ID       32484 non-null  object
#  2   Order Date     32484 non-null  datetime64[ns]
#  3   Ship Date      32484 non-null  datetime64[ns]
#  4   Ship Mode      32484 non-null  object
#  5   Customer ID    32484 non-null  object
#  6   Customer Name  32484 non-null  object
#  7   Segment        32484 non-null  object
#  8   Country        32484 non-null  object
#  9   City           32484 non-null  object
#  10  State          32484 non-null  object
#  11  Postal Code    32482 non-null  object
#  12  Region         32484 non-null  object
#  13  Product ID     32484 non-null  object
#  14  Category       32484 non-null  object
#  15  Sub-Category   32484 non-null  object
#  16  Product Name   32484 non-null  object
# ...

# %%
# Get the current date
current_date = datetime.now().date()

# %%
# Filter the dataframe to include only rows with 'Order Date' up to the current date
df_filtered = df[df['Order Date'].dt.date <= current_date]

# %%
# Create a 'YearMonth' column for grouping
df_filtered['YearMonth'] = df_filtered['Order Date'].dt.to_period('M')
df_filtered['Year'] = df_filtered['Order Date'].dt.year

# Group by 'YearMonth'
groups = df_filtered.groupby('YearMonth')

df_filtered.head()
# Out:
# C:\Users\luay9\AppData\Local\Temp\ipykernel_16476\3544414134.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered['YearMonth'] = df_filtered['Order Date'].dt.to_period('M')
# C:\Users\luay9\AppData\Local\Temp\ipykernel_16476\3544414134.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered['Year'] = df_filtered['Order Date'].dt.year
#    Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# ...

# %%
# Create a new folder for the CSV files
output_folder = 'MonthlyData'
os.makedirs(output_folder, exist_ok=True)

# %%
# Save each group to a separate CSV file in the appropriate year folder
for name, group in groups:
    # Extract year from the group name
    year = str(name.year)
    # Create year folder if it doesn't exist
    year_folder = os.path.join(output_folder, year)
    os.makedirs(year_folder, exist_ok=True)
    # Format the filename as 'Superstore_YYYY-MM.csv' inside the year folder
    filename = os.path.join(year_folder, f'Superstore_{name}.csv')
    # Save the group to a CSV file
    group.to_csv(filename, index=False)
